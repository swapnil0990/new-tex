# %%
import matplotlib.pyplot as plt

# %%
time_w1 = [2,5,7,8,9,12]
act_w2 = ["sleeping","reading","watching","playing","gym","gaming"]

# %%
plt.axis("equal")
plt.pie(time_w1, labels= act_w2, autopct = "%f%%", explode = [0,0.7,0.5,0,0,0],radius = 1.5)
plt.show()
